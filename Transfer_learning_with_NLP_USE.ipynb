# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/xebia_training_data/blob/main/Transfer_learning_with_NLP_USE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer learning using Universal Sentence Encoder

# %% [markdown]
# ## Import packages

# %%
# import the packages
import tensorflow_hub as hub
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re

# %% [markdown]
# ## Downloading the model

# %%
model_url = "https://tfhub.dev/google/universal-sentence-encoder-large/5"
embed = hub.load(model_url)


# Compute a representation for each message, showing various lengths supported.
word = "Elephant"
sentence = "I am a sentence for which I would like to get its embedding."
paragraph = (
    "Universal Sentence Encoder embeddings also support short paragraphs. "
    "There is no hard limit on how long the paragraph is. Roughly, the longer "
    "the more 'diluted' the embedding will be.")
messages = [word, sentence, paragraph]

# %%
embed(messages)
# Out:
# <tf.Tensor: shape=(3, 512), dtype=float32, numpy=
# array([[-0.03458559, -0.01799013,  0.00198059, ...,  0.1110782 ,
#         -0.03549768,  0.05680298],
#        [ 0.05833391, -0.08185009,  0.06890938, ..., -0.00923875,
#         -0.0869535 , -0.01415742],
#        [-0.02646175, -0.01911564, -0.0420704 , ..., -0.00689677,
#          0.01810371, -0.02591053]], dtype=float32)>

# %%
embed([word])
# Out:
# <tf.Tensor: shape=(1, 512), dtype=float32, numpy=
# array([[-3.45856175e-02, -1.79901328e-02,  1.98055757e-03,
#          4.07285355e-02, -1.03552202e-02,  6.11353293e-02,
#          3.75662670e-02, -2.61142175e-03,  1.79612450e-02,
#         -4.68622446e-02,  2.23783739e-02, -6.13366952e-03,
#          1.23131208e-01, -5.41218258e-02, -3.82820852e-02,
#         -1.59519911e-02, -3.25838216e-02, -4.26743738e-02,
#         -6.10241527e-03, -5.40403053e-02,  5.07151820e-02,
#          3.01326867e-02,  5.43540157e-02, -3.47163677e-02,
#          8.15961137e-02, -5.37351221e-02, -7.82470126e-03,
#         -2.36683171e-02,  1.05400123e-02,  3.99180921e-03,
#          1.64848857e-03,  2.44230381e-03, -3.78189720e-02,
#          6.28115535e-02,  2.53320532e-03, -7.68776760e-02,
#         -1.40247289e-02,  5.79064786e-02,  4.62107249e-02,
#         -4.96760197e-02, -7.21461698e-02, -1.11357227e-01,
#          2.80168392e-02,  3.13003212e-02, -3.87154035e-02,
#          1.03799393e-02, -1.41457111e-01,  1.55930407e-02,
#         -6.04910739e-02, -2.94040591e-02, -9.08551924e-03,
#          1.36433495e-02, -1.52381379e-02, -2.39247512e-02,
#          1.62116569e-02,  9.80901159e-03,  1.81801654e-02,
#          5.55939935e-02,  5.70754111e-02, -5.87063245e-02,
#         -2.99255084e-02, -8.26841127e-03, -4.59861243e-04,
#          4.95626181e-02, -7.61263072e-02,  2.96747694e-05,
#          3.58698480e-02,  2.20421944e-02,  6.52691815e-03,
#         -6.09660037e-02, -1.96148045e-02,  8.09744522e-02,
#          2.35933289e-02, -1.35614984e-02, -2.45748870e-02,
#         -8.62467512e-02, -5.98957464e-02, -5.80040216e-02,
#          1.99940298e-02,  1.27324155e-02, -1.22116534e-02,
#          4.95293587e-02, -6.21927045e-02,  3.21096405e-02,
#         -2.45758928e-02, -1.08381603e-02,  1.39440224e-02,
#         -4.30933237e-02, -2.60117296e-02,  6.61562383e-02,
#         -5.70543110e-02,  6.42854646e-02, -1.95537638e-02,
#          2.15025805e-03,  9.14070569e-03,  1.26839867e-02,
#          9.93752200e-03,  8.06639344e-03,  1.20452289e-02,
#          1.02161869e-01,  3.36656943e-02, -8.57507996e-03,
#          9.59022902e-03,  1.00157149e-02, -5.14907986e-02,
#         -6.85311481e-03, -2.55222414e-02,  2.71763634e-02,
#          1.55976526e-02, -7.98048899e-02,  1.74380913e-02,
#         -4.96195555e-02, -1.97453257e-02, -5.26632406e-02,
#          9.06706881e-03,  1.41947409e-02, -1.42673322e-04,
#         -1.27874576e-02,  4.80506867e-02,  9.44912247e-03,
#          2.33335793e-02,  1.74858551e-02, -2.60273535e-02,
#          3.40339653e-02,  1.75180919e-02,  2.94533297e-02,
#          8.70439336e-02,  1.04263574e-02,  7.28293322e-03,
#         -2.00555995e-02, -8.03029398e-04,  6.93142116e-02,
#          1.68543644e-02, -8.92112905e-04, -7.27671245e-03,
#         -6.07063137e-02,  3.11647896e-02,  5.06766811e-02,
#          1.91151276e-02, -7.20643671e-03, -2.14247424e-02,
#          6.05559610e-02, -3.32929268e-02,  3.04078497e-02,
#         -7.15655908e-02,  5.84067069e-02,  3.62483636e-02,
#          4.69455589e-03,  1.93292368e-02,  4.43179421e-02,
#          7.12241605e-02,  4.39459682e-02, -9.67815332e-03,
#          1.23626711e-02,  1.37344413e-02, -5.76521754e-02,
#          5.09548225e-02,  3.14359665e-02,  7.75816292e-02,
#         -3.84285040e-02, -3.46182212e-02,  3.24578173e-02,
#         -3.71656604e-02,  3.61785851e-02, -8.24336056e-03,
#          3.83340493e-02, -1.36963464e-02,  8.74527469e-02,
#          1.79732610e-02,  5.79408891e-02,  2.77484544e-02,
#         -4.30810787e-02,  9.15720388e-02, -1.18153496e-02,
#         -9.20910668e-03, -2.67051328e-02,  2.62438077e-02,
#          3.05955485e-02,  8.59783217e-02, -3.70002165e-03,
#          1.10382870e-01,  1.55771092e-01, -5.95676415e-02,
#          1.12963459e-02,  4.71027195e-03, -2.25301180e-02,
#         -1.13187119e-01, -2.40785610e-02, -5.39944470e-02,
#         -3.50812301e-02, -5.43226413e-02,  5.87365963e-02,
#         -1.45391282e-02, -3.59623171e-02,  2.98933834e-02,
#          8.83317143e-02,  1.22067742e-02, -1.99052431e-02,
#          1.32855326e-01, -2.32943408e-02, -3.45243216e-02,
#          1.58798508e-02,  5.18729202e-02,  3.51571813e-02,
#         -4.24405979e-03,  1.07905676e-03, -3.74839008e-02,
#         -3.27034034e-02, -2.80124769e-02, -5.22373840e-02,
#          3.63478884e-02, -2.67687552e-02,  1.11078210e-01,
#         -3.54977064e-02,  5.68030179e-02]], dtype=float32)>

# %%
for doc in messages:
  print(doc)
  print(len(embed([doc])[0]))
  print("\n")
# Out:
# Elephant
# 512
#
#
# I am a sentence for which I would like to get its embedding.
# 512
#
#
# Universal Sentence Encoder embeddings also support short paragraphs. There is no hard limit on how long the paragraph is. Roughly, the longer the more 'diluted' the embedding will be.
# 512

# %%
#size of embedding

# %% [markdown]
# ## Download data

# %%
# !wget -q https://raw.githubusercontent.com/Tony607/Keras-Text-Transfer-Learning/master/train_5500.txt
# !wget -q https://raw.githubusercontent.com/Tony607/Keras-Text-Transfer-Learning/master/test_data.txt

# %% [markdown]
# ## Decscription of Data

# %% [markdown]
# The dataset we use is the TREC Question Classification dataset, There are entirely 5452 training and 500 test samples, that is 5452 + 500 questions each categorized into one of the six labels.
#
# - ABBR - 'abbreviation': expression abbreviated, etc.
# - DESC - 'description and abstract concepts': manner of an action, description of sth. etc.
# - ENTY - 'entities': animals, colors, events, food, etc.
# - HUM - 'human beings': a group or organization of persons, an individual, etc.
# - LOC - 'locations': cities, countries, etc.
# - NUM - 'numeric values': postcodes, dates, speed,temperature, etc

# %%
#Extract lines from .txt and convert to dataframe

def get_dataframe(filename):
    lines = open(filename, 'r').read().splitlines()
    data = []
    for i in range(0, len(lines)):
        label = lines[i].split(' ')[0]
        label = label.split(":")[0]
        text = ' '.join(lines[i].split(' ')[1:])
        text = re.sub('[^A-Za-z0-9 ,\?\'\"-._\+\!/\`@=;:]+', '', text)
        data.append([label, text])

    df = pd.DataFrame(data, columns=['label', 'text'])
    df.label = df.label.astype('category')
    return df

# %%
#Assign train data
df_train = get_dataframe("/content/train_5500.txt")
df_test = get_dataframe("/content/test_data.txt")

print(df_train.shape)
print(df_test.shape)
# Out:
# (5452, 2)
# (500, 2)

# %%
df_train.head(10)
# Out:
#   label                                               text
# 0  DESC  How did serfdom develop in and then leave Russ...
# 1  ENTY   What films featured the character Popeye Doyle ?
# 2  DESC  How can I find a list of celebrities ' real na...
# 3  ENTY  What fowl grabs the spotlight after the Chines...
# 4  ABBR                    What is the full form of .com ?
# 5   HUM  What contemptible scoundrel stole the cork fro...
# 6   HUM  What team did baseball 's St. Louis Browns bec...
# 7   HUM                    What is the oldest profession ?
# 8  DESC                           What are liver enzymes ?
# 9   HUM  Name the scar-faced bounty hunter of The Old W...

# %%
#Number of categories in dataset
category_counts = len(df_train.label.cat.categories)
category_counts
# Out:
# 6

# %%
#Convert input into strings  
def UniversalEmbedding(x):
    return embed(tf.squeeze(tf.cast(x,tf.string),axis=1))

# %%
UniversalEmbedding([['hello']]).shape
# Out:
# TensorShape([1, 512])

# %% [markdown]
# ## Model Building

# %%
from tensorflow.keras import models,layers

# %%
input_layer = layers.Input(shape=(1,),dtype=tf.string)
hub_layer = layers.Lambda(UniversalEmbedding,output_shape=(512,))(input_layer)
dense1 = layers.Dense(256,activation='relu')(hub_layer)
output_layer = layers.Dense(6,activation='softmax')(dense1)

model = models.Model(inputs=[input_layer],outputs=output_layer)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda), but
# are not present in its tracked objects:
#   <tf.Variable 'Embeddings/sharded_0:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_1:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_2:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_3:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_4:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_5:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_6:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_7:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_8:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_9:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_10:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_11:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_12:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_13:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_14:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_15:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_16:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_17:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_18:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_19:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_20:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_21:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_22:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_23:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_24:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded_25:0' shape=(13334, 320) dtype=float32>
#   <tf.Variable 'Embeddings/sharded
0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_scale/part_29:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_0:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_1:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_2:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_3:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_4:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_5:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_6:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_7:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_8:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_9:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_10:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_11:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_12:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_13:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_14:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_15:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_16:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_17:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_18:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_19:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_20:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_21:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_22:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/layer_prepostprocess/layer_norm/layer_norm_bias/part_29:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_0:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_1:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_2:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_3:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_4:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_5:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_6:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_7:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_8:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_9:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_10:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_11:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_12:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_13:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_14:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_15:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_16:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_17:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_18:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_19:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_20:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_21:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_22:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_q/bias/part_29:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/SparseTransformerEncode/Layer_0/SelfAttention/SparseMultiheadAttention/ComputeQKV/compute_k/kernel/part_9:0' shape=(17, 512) dtype=float32>
# ...
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_19:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_20:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_21:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_22:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionHidden/bias/part_29:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_0:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_1:0' shape=(18, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_2:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_3:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_4:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_5:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_6:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_7:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_8:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_9:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_10:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_11:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_12:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_13:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_14:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_15:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_16:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_17:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_18:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_19:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_20:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_21:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_22:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_23:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_24:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_25:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_26:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_27:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_28:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/kernel/part_29:0' shape=(17, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_0:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_1:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_2:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_3:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_4:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_5:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_6:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_7:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_8:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_9:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_10:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_11:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_12:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_13:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_14:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_15:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_16:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_17:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_18:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_19:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_20:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_21:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_22:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/Transformer/AttentionPooling/AttentionLogits/bias/part_29:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_0:0' shape=(35, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_1:0' shape=(35, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_2:0' shape=(35, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_3:0' shape=(35, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_4:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_5:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_6:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_7:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_8:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_9:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_10:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_11:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_12:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_13:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_14:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_15:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_16:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_17:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_18:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_19:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_20:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_21:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_22:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_23:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_24:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_25:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_26:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_27:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_28:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/kernel/part_29:0' shape=(34, 512) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_0:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_1:0' shape=(18,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_2:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_3:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_4:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_5:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_6:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_7:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_8:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_9:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_10:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_11:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_12:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_13:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_14:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_15:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_16:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_17:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_18:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_19:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_20:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_21:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_22:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_23:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_24:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_25:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_26:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_27:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_28:0' shape=(17,) dtype=float32>
#   <tf.Variable 'EncoderTransformer/hidden_layers/tanh_layer_0/dense/bias/part_29:0' shape=(17,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# lambda (Lambda)              (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 132,870
# Trainable params: 132,870
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Convert train text to  an array and labels as get_dummies
xtrain = df_train['text'].tolist()
xtrain = np.array(xtrain).reshape(-1,1)
print(xtrain.shape)
xtest = df_test['text'].tolist()
xtest = np.array(xtest).reshape(-1,1)
print(xtest.shape)
# Out:
# (5452, 1)
# (500, 1)

# %%
categories = list(pd.get_dummies(df_train['label']).columns)
categories = [i[2:] for i in categories]
categories
# Out:
# ['BR', 'SC', 'TY', 'M', 'C', 'M']

# %%
ytrain = np.array(pd.get_dummies(df_train['label']))
ytest = np.array(pd.get_dummies(df_test['label']))
print(ytrain.shape)
print(ytest.shape)
# Out:
# (5452, 6)
# (500, 6)

# %%
model.fit(xtrain,ytrain,epochs=10,batch_size=32,validation_data=(xtest,ytest))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/EncoderTransformer/EmbeddingLookup/EmbeddingLookupUnique/GatherV2_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/EncoderTransformer/EmbeddingLookup/EmbeddingLookupUnique/GatherV2_grad/Reshape:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradients/EncoderTransformer/EmbeddingLookup/EmbeddingLookupUnique/GatherV2_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 171/171 [==============================] - 49s 58ms/step - loss: 1.2484 - accuracy: 0.6142 - val_loss: 0.2579 - val_accuracy: 0.9360
# Epoch 2/10
# 171/171 [==============================] - 6s 34ms/step - loss: 0.3004 - accuracy: 0.9202 - val_loss: 0.1538 - val_accuracy: 0.9580
# Epoch 3/10
# 171/171 [==============================] - 6s 34ms/step - loss: 0.2062 - accuracy: 0.9373 - val_loss: 0.1392 - val_accuracy: 0.9520
# Epoch 4/10
# 171/171 [==============================] - 5s 32ms/step - loss: 0.1665 - accuracy: 0.9496 - val_loss: 0.1225 - val_accuracy: 0.9540
# Epoch 5/10
# 171/171 [==============================] - 6s 34ms/step - loss: 0.1402 - accuracy: 0.9560 - val_loss: 0.1160 - val_accuracy: 0.9640
# Epoch 6/10
# 171/171 [==============================] - 6s 33ms/step - loss: 0.1219 - accuracy: 0.9656 - val_loss: 0.1075 - val_accuracy: 0.9680
# Epoch 7/10
# 171/171 [==============================] - 6s 34ms/step - loss: 0.1142 - accuracy: 0.9629 - val_loss: 0.1318 - val_accuracy: 0.9500
# Epoch 8/10
# 171/171 [==============================] - 6s 34ms/step - loss: 0.0985 - accuracy: 0.9719 - val_loss: 0.1364 - val_accuracy: 0.9460
# Epoch 9/10
# 171/171 [==============================] - 6s 33ms/step - loss: 0.0916 - accuracy: 0.9706 - val_loss: 0.1244 - val_accuracy: 0.9500
# Epoch 10/10
# 171/171 [==============================] - 5s 32ms/step - loss: 0.0840 - accuracy: 0.9765 - val_loss: 0.1199 - val_accuracy: 0.9520

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, dpi=96)

# %% [markdown]
# ## Train the model

# %% [markdown]
# ## Test the model

# %%
 model.save_weights("model.h5")

# %%
new_doc = ["Who is president of United States of America?","What is price for Harley Davidson?"]
new_doc = np.array(new_doc).reshape(-1,1)

model.load_weights("model.h5")
output = model.predict(new_doc)

# %%
output
# Out:
# array([[4.36984379e-07, 2.73933051e-06, 1.06767138e-05, 9.99978423e-01,
#         7.47359809e-06, 9.67461702e-08],
#        [2.55255309e-05, 5.17500378e-03, 6.63594808e-04, 9.68002132e-06,
#         1.01536925e-05, 9.94115949e-01]], dtype=float32)

# %%
output2 = [np.argmax(i) for i in output]
output2
# Out:
# [3, 5]

# %%
categories = list(pd.get_dummies(df_train['label']).columns)
output2 = [categories[i] for i in output2]
output2
# Out:
# ['HUM', 'NUM']
